# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Inc_Exp_Data.csv')

# %%
print(data.shape)
print(data.describe())
print(data.head)
# Out:
# (50, 7)
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
income =data['Mthly_HH_Income'].values
spend = data['Mthly_HH_Expense'].values
x= np.array(list(zip(income,spend)))
x
# Out:
# array([[  5000,   8000],
#        [  6000,   7000],
#        [ 10000,   4500],
#        [ 10000,   2000],
#        [ 12500,  12000],
#        [ 14000,   8000],
#        [ 15000,  16000],
#        [ 18000,  20000],
#        [ 19000,   9000],
#        [ 20000,   9000],
#        [ 20000,  18000],
#        [ 22000,  25000],
#        [ 23400,   5000],
#        [ 24000,  10500],
#        [ 24000,  10000],
#        [ 25000,  12300],
#        [ 25000,  20000],
#        [ 25000,  10000],
#        [ 29000,   6600],
#        [ 30000,  13000],
#        [ 30500,  25000],
#        [ 32000,  15000],
#        [ 34000,  19000],
#        [ 34000,  25000],
#        [ 35000,  12000],
#        [ 35000,  25000],
#        [ 39000,   8000],
#        [ 40000,  10000],
#        [ 42000,  15000],
#        [ 43000,  12000],
#        [ 45000,  25000],
#        [ 45000,  40000],
#        [ 45000,  10000],
#        [ 45000,  22000],
#        [ 46000,  25000],
#        [ 47000,  15000],
#        [ 50000,  20000],
# ...

# %% [markdown]
# **k number finding**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,10):
    km=KMeans(n_clusters=i,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)

plt.plot(range(1,10),wcss, color="red",marker="8")
plt.title("optimal k value")
plt.xlabel("number of clusters")
plt.ylabel("WCSS")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model=KMeans(n_clusters=4, random_state=0)
y_means=model.fit_predict(x)

# %%
plt.scatter(x[y_means==0,0],x[y_means==0,1],s=50, c='brown',label='1')
plt.scatter(x[y_means==1,0],x[y_means==1,1],s=50, c='blue',label='1')
plt.scatter(x[y_means==2,0],x[y_means==2,1],s=50, c='green',label='1')
plt.scatter(x[y_means==3,0],x[y_means==3,1],s=50, c='red',label='1')
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],s=100,marker='s',c='red',label='centroids')
plt.title("Income Analysis")
plt.xlabel("income")
plt.ylabel("spent")
plt.legend()
plt.show()
